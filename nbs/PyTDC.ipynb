# %%
# !pip install PyTDC
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.7/107.7 kB 3.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.4/29.4 MB 40.7 MB/s eta 0:00:00
# ...
#   Created wheel for PyTDC: filename=PyTDC-0.4.1-py3-none-any.whl size=140644 sha256=8334a6281f6106a8e708c059c11f7f7fb3cfc66caed023d64b26aaa71be17012
#   Stored in directory: /root/.cache/pip/wheels/14/b7/b8/9d9e1442129743359b0507234ccc0beb67b47173faccd57d54
# Successfully built PyTDC
# ...

# %%
from tdc.utils import retrieve_label_name_list
label_list = retrieve_label_name_list('Tox21')

# %%
label_list
# Out:
# ['NR-AR',
#  'NR-AR-LBD',
#  'NR-AhR',
#  'NR-Aromatase',
#  'NR-ER',
#  'NR-ER-LBD',
#  'NR-PPAR-gamma',
#  'SR-ARE',
#  'SR-ATAD5',
#  'SR-HSE',
#  'SR-MMP',
#  'SR-p53']

# %%
from tdc.single_pred import Tox
data = Tox(name = 'Tox21', label_name = label_list[0])
split = data.get_split()
# Out:
# Downloading...
# 100%|██████████| 712k/712k [00:00<00:00, 2.82MiB/s]
# Loading...
# Done!

# %%
split
# Out:
# {'train':        Drug_ID                                               Drug    Y
#  0      TOX3020                          CCN1C(=O)NC(c2ccccc2)C1=O  0.0
#  1      TOX3027                    CCCN(CC)C(CC)C(=O)Nc1c(C)cccc1C  0.0
#  2     TOX20800                          CC(O)(P(=O)(O)O)P(=O)(O)O  0.0
#  3      TOX5110               CC(C)(C)OOC(C)(C)CCC(C)(C)OOC(C)(C)C  0.0
#  4     TOX25232             O=C(O)Cc1cc(I)c(Oc2ccc(O)c(I)c2)c(I)c1  0.0
#  ...        ...                                                ...  ...
#  5081  TOX25182    Cc1nc2ccccn2c(=O)c1CCN1CCC(C(=O)c2ccc(F)cc2)CC1  0.0
#  5082  TOX25180                                NC(=O)CN1CC(O)CC1=O  0.0
#  5083  TOX25184                 CCCNCC(O)COc1ccccc1C(=O)CCc1ccccc1  0.0
#  5084   TOX2371  C[C@]12CC[C@H]3[C@@H](CCC4=CC(=O)CC[C@@]43C)[C...  1.0
#  5085   TOX2377  C[C@]12CC[C@@H]3c4ccc(O)cc4CC[C@H]3[C@@H]1CC[C...  1.0
#
#  [5086 rows x 3 columns],
# ...

# %%
split['train']
# Out:
#        Drug_ID                                               Drug    Y
# 0      TOX3020                          CCN1C(=O)NC(c2ccccc2)C1=O  0.0
# 1      TOX3027                    CCCN(CC)C(CC)C(=O)Nc1c(C)cccc1C  0.0
# 2     TOX20800                          CC(O)(P(=O)(O)O)P(=O)(O)O  0.0
# 3      TOX5110               CC(C)(C)OOC(C)(C)CCC(C)(C)OOC(C)(C)C  0.0
# 4     TOX25232             O=C(O)Cc1cc(I)c(Oc2ccc(O)c(I)c2)c(I)c1  0.0
# ...        ...                                                ...  ...
# 5081  TOX25182    Cc1nc2ccccn2c(=O)c1CCN1CCC(C(=O)c2ccc(F)cc2)CC1  0.0
# 5082  TOX25180                                NC(=O)CN1CC(O)CC1=O  0.0
# 5083  TOX25184                 CCCNCC(O)COc1ccccc1C(=O)CCc1ccccc1  0.0
# 5084   TOX2371  C[C@]12CC[C@H]3[C@@H](CCC4=CC(=O)CC[C@@]43C)[C...  1.0
# 5085   TOX2377  C[C@]12CC[C@@H]3c4ccc(O)cc4CC[C@H]3[C@@H]1CC[C...  1.0
#
# [5086 rows x 3 columns]

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/tox21-mitotox-p1_aggregrated.csv')

# %%
df.columns
# Out:
# Index(['SAMPLE_ID', 'PROTOCOL_NAME', 'SAMPLE_DATA_TYPE', 'ASSAY_OUTCOME',
#        'CHANNEL_OUTCOME', 'AC50', 'EFFICACY', 'REPRODUCIBILITY', 'CURVE_RANK',
#        'FLAG', 'CAS', 'PUBCHEM_CID', 'PUBCHEM_SID', 'PURITY_RATING',
#        'PURITY_RATING_4M', 'SAMPLE_NAME', 'SMILES', 'TOX21_ID', 'PURITY'],
#       dtype='object')

# %%
df.ASSAY_OUTCOME.value_counts()
# Out:
# inactive                               27240
# active antagonist                       5052
# inconclusive                            4040
# inconclusive agonist                    1508
# inconclusive antagonist (cytotoxic)     1504
# inconclusive antagonist                 1424
# active agonist                          1188
# inconclusive agonist (cytotoxic)          28
# Name: ASSAY_OUTCOME, dtype: int64

# %%
df.TOX21_ID.value_counts()
# Out:
# Tox21_110019    4
# Tox21_110026    4
# Tox21_110020    4
# Tox21_110021    4
# Tox21_110022    4
#                ..
# Tox21_303225    4
# Tox21_303266    4
# Tox21_303281    4
# Tox21_303310    4
# Tox21_303324    4
# Name: TOX21_ID, Length: 10496, dtype: int64

# %%
df.query('TOX21_ID == "Tox21_303310"')
# Out:
#              SAMPLE_ID     PROTOCOL_NAME SAMPLE_DATA_TYPE ASSAY_OUTCOME  \
# 14946  NCGC00257232-01  tox21-mitotox-p1         activity  inconclusive
# 19261  NCGC00257232-01  tox21-mitotox-p1          control  inconclusive
# 25250  NCGC00257232-01  tox21-mitotox-p1           signal  inconclusive
# 39719  NCGC00257232-01  tox21-mitotox-p1        viability  inconclusive
#
#                CHANNEL_OUTCOME       AC50   EFFICACY REPRODUCIBILITY  \
# 14946  inconclusive antagonist  45.841457 -42.249822    inconclusive
# 19261                 inactive        NaN   0.000000  inactive_match
# 25250                 inactive        NaN   0.000000  inactive_match
# 39719                 inactive        NaN   0.000000  inactive_match
#
#        CURVE_RANK                             FLAG      CAS  PUBCHEM_CID  \
# 14946    -2.66667  blue (460 nm) auto fluorescent;  87-02-5       6868.0
# 19261     0.00000  blue (460 nm) auto fluorescent;  87-02-5       6868.0
# ...

# %%
df.CHANNEL_OUTCOME.value_counts()
# Out:
# inactive                   32718
# active antagonist           3945
# inconclusive agonist        2051
# inconclusive antagonist     1817
# active agonist              1274
# inconclusive                 179
# Name: CHANNEL_OUTCOME, dtype: int64
